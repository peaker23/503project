# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/lib/python3.12/site-packages (8.3.40)
# Requirement already satisfied: numpy>=1.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8m.pt")

# %%
results = model.predict("1.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/1.jpg: 480x640 (no detections), 139.1ms
# Speed: 1.9ms preprocess, 139.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 0

# %%
#you can analyze each box either in a loop or manually.
box = result.boxes[0]
print("Object type:", box.cls)
print("Coordinates:", box.xyxy)
print("Probability:", box.conf)
# Out:
# Object type: tensor([5.])
# Coordinates: tensor([[126.3939, 470.6309, 555.2277, 713.9147]])
# Probability: tensor([0.9463])

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")

# %%
results = model.predict("2.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/2.jpg: 480x640 12 persons, 3 backpacks, 1 handbag, 7 tvs, 1 clock, 145.0ms
# Speed: 3.6ms preprocess, 145.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 24

# %%
#you can analyze each box either in a loop or manually.
box = result.boxes[0]
print("Object type:", box.cls)
print("Coordinates:", box.xyxy)
print("Probability:", box.conf)
# Out:
# Object type: tensor([62.])
# Coordinates: tensor([[358.9035,  35.7799, 573.1845, 211.5742]])
# Probability: tensor([0.9384])

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")
# Out:
# Object type: tv
# Coordinates: [359, 36, 573, 212]
# Probability: 0.94
#
# Next Object
# Object type: tv
# Coordinates: [38, 0, 360, 198]
# Probability: 0.92
#
# Next Object
# Object type: person
# Coordinates: [0, 312, 103, 480]
# Probability: 0.91
#
# Next Object
# Object type: tv
# Coordinates: [572, 76, 640, 217]
# Probability: 0.8
#
# Next Object
# Object type: person
# Coordinates: [343, 319, 393, 449]
# Probability: 0.8
#
# Next Object
# Object type: person
# Coordinates: [549, 328, 615, 480]
# Probability: 0.79
#
# Next Object
# Object type: tv
# Coordinates: [474, 268, 510, 295]
# Probability: 0.78
#
# Next Object
# Object type: person
# Coordinates: [229, 334, 264, 456]
# Probability: 0.76
#
# Next Object
# Object type: tv
# Coordinates: [437, 269, 477, 295]
# Probability: 0.76
#
# Next Object
# Object type: person
# Coordinates: [387, 313, 429, 430]
# Probability: 0.75
#
# Next Object
# Object type: person
# Coordinates: [186, 356, 227, 464]
# Probability: 0.68
#
# Next Object
# Object type: handbag
# Coordinates: [361, 337, 388, 391]
# Probability: 0.63
#
# Next Object
# Object type: person
# Coordinates: [288, 309, 315, 413]
# Probability: 0.61
#
# Next Object
# Object type: backpack
# Coordinates: [234, 353, 260, 392]
# Probability: 0.6
#
# Next Object
# Object type: person
# Coordinates: [128, 320, 172, 449]
# Probability: 0.59
#
# Next Object
# Object type: tv
# Coordinates: [0, 0, 44, 177]
# Probability: 0.51
#
# Next Object
# Object type: person
# Coordinates: [326, 315, 351, 385]
# Probability: 0.38
#
# Next Object
# Object type: tv
# Coordinates: [577, 287, 617, 311]
# Probability: 0.37
#
# Next Object
# Object type: person
# Coordinates: [195, 324, 226, 359]
# Probability: 0.35
#
# Next Object
# Object type: backpack
# Coordinates: [0, 352, 55, 436]
# Probability: 0.34
#
# Next Object
# Object type: person
# Coordinates: [517, 310, 538, 356]
# Probability: 0.32
#
# Next Object
# Object type: person
# Coordinates: [0, 327, 16, 378]
# Probability: 0.32
#
# Next Object
# Object type: clock
# Coordinates: [394, 260, 408, 279]
# Probability: 0.3
#
# Next Object
# Object type: backpack
# Coordinates: [390, 334, 419, 371]
# Probability: 0.25
#
# Next Object

# %%
results = model.predict("3.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/3.jpg: 320x640 4 sheeps, 1 cow, 3 bears, 114.8ms
# Speed: 3.5ms preprocess, 114.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 8

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")
# Out:
# Object type: bear
# Coordinates: [331, 63, 465, 259]
# Probability: 0.94
#
# Next Object
# Object type: sheep
# Coordinates: [522, 266, 776, 391]
# Probability: 0.52
#
# Next Object
# Object type: bear
# Coordinates: [455, 172, 709, 297]
# Probability: 0.49
#
# Next Object
# Object type: sheep
# Coordinates: [679, 324, 799, 398]
# Probability: 0.46
#
# Next Object
# Object type: sheep
# Coordinates: [64, 65, 313, 164]
# Probability: 0.4
#
# Next Object
# Object type: cow
# Coordinates: [678, 325, 800, 399]
# Probability: 0.31
#
# Next Object
# Object type: sheep
# Coordinates: [704, 200, 799, 281]
# Probability: 0.29
#
# Next Object
# Object type: bear
# Coordinates: [64, 65, 314, 163]
# Probability: 0.27
#
# Next Object

# %%
results = model.predict("4.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/4.jpg: 384x640 18 persons, 1 backpack, 1 handbag, 2 bottles, 2 cups, 1 chair, 1 dining table, 10 books, 114.3ms
# Speed: 1.7ms preprocess, 114.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 36

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")
# Out:
# Object type: person
# Coordinates: [641, 309, 917, 542]
# Probability: 0.93
#
# Next Object
# Object type: person
# Coordinates: [164, 282, 449, 503]
# Probability: 0.91
#
# Next Object
# Object type: person
# Coordinates: [738, 140, 915, 249]
# Probability: 0.87
#
# Next Object
# Object type: person
# Coordinates: [0, 265, 170, 450]
# Probability: 0.86
#
# Next Object
# Object type: person
# Coordinates: [870, 324, 1024, 477]
# Probability: 0.8
#
# Next Object
# Object type: person
# Coordinates: [104, 151, 254, 281]
# Probability: 0.79
#
# Next Object
# Object type: person
# Coordinates: [257, 170, 384, 274]
# Probability: 0.76
#
# Next Object
# Object type: person
# Coordinates: [349, 53, 458, 177]
# Probability: 0.74
#
# Next Object
# Object type: book
# Coordinates: [0, 395, 161, 561]
# Probability: 0.69
#
# Next Object
# Object type: cup
# Coordinates: [978, 478, 1024, 560]
# Probability: 0.66
#
# Next Object
# Object type: person
# Coordinates: [549, 70, 675, 165]
# Probability: 0.65
#
# Next Object
# Object type: cup
# Coordinates: [709, 157, 731, 186]
# Probability: 0.62
#
# Next Object
# Object type: book
# Coordinates: [55, 487, 276, 575]
# Probability: 0.58
#
# Next Object
# Object type: chair
# Coordinates: [143, 366, 200, 423]
# Probability: 0.57
#
# Next Object
# Object type: book
# Coordinates: [294, 472, 377, 552]
# Probability: 0.54
#
# Next Object
# Object type: book
# Coordinates: [829, 471, 1017, 574]
# Probability: 0.53
#
# Next Object
# Object type: bottle
# Coordinates: [947, 89, 977, 143]
# Probability: 0.5
#
# Next Object
# Object type: person
# Coordinates: [207, 97, 333, 188]
# Probability: 0.48
#
# Next Object
# Object type: handbag
# Coordinates: [137, 287, 210, 321]
# Probability: 0.48
#
# Next Object
# Object type: backpack
# Coordinates: [482, 230, 575, 353]
# Probability: 0.48
#
# Next Object
# Object type: book
# Coordinates: [258, 462, 432, 574]
# Probability: 0.41
#
# Next Object
# Object type: person
# Coordinates: [895, 29, 1021, 226]
# Probability: 0.41
#
# Next Object
# Object type: person
# Coordinates: [543, 140, 701, 468]
# Probability: 0.41
#
# Next Object
# Object type: person
# Coordinates: [0, 111, 59, 270]
# Probability: 0.39
#
# Next Object
# Object type: book
# Coordinates: [237, 428, 384, 509]
# Probability: 0.39
#
# Next Object
# Object type: person
# Coordinates: [829, 19, 910, 131]
# Probability: 0.34
#
# Next Object
# Object type: person
# Coordinates: [654, 29, 721, 98]
# Probability: 0.34
#
# Next Object
# Object type: dining table
# Coordinates: [901, 126, 1023, 172]
# Probability: 0.34
#
# Next Object
# Object type: person
# Coordinates: [543, 138, 703, 327]
# Probability: 0.31
#
# Next Object
# Object type: person
# Coordinates: [540, 9, 621, 103]
# Probability: 0.29
#
# Next Object
# Object type: book
# Coordinates: [581, 214, 749, 297]
# Probability: 0.28
#
# Next Object
# Object type: book
# Coordinates: [26, 116, 110, 143]
# Probability: 0.27
#
# Next Object
# Object type: bottle
# Coordinates: [578, 140, 597, 183]
# Probability: 0.27
#
# Next Object
# Object type: book
# Coordinates: [884, 227, 1015, 281]
# Probability: 0.27
#
# Next Object
# Object type: person
# Coordinates: [897, 30, 1020, 124]
# Probability: 0.27
#
# Next Object
# Object type: book
# Coordinates: [767, 116, 862, 169]
# Probability: 0.26
#
# Next Object

# %%
results = model.predict("5.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/5.jpg: 384x640 5 persons, 1 tie, 1 cup, 3 chairs, 2 dining tables, 2 tvs, 108.3ms
# Speed: 1.8ms preprocess, 108.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 14

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")
# Out:
# Object type: tv
# Coordinates: [2774, 300, 4029, 1545]
# Probability: 0.93
#
# Next Object
# Object type: tv
# Coordinates: [1, 429, 1380, 1508]
# Probability: 0.93
#
# Next Object
# Object type: person
# Coordinates: [603, 1484, 1503, 2257]
# Probability: 0.91
#
# Next Object
# Object type: person
# Coordinates: [499, 1569, 928, 2245]
# Probability: 0.86
#
# Next Object
# Object type: person
# Coordinates: [1945, 1223, 2468, 2232]
# Probability: 0.73
#
# Next Object
# Object type: chair
# Coordinates: [1221, 1893, 1641, 2260]
# Probability: 0.72
#
# Next Object
# Object type: cup
# Coordinates: [20, 1776, 186, 1943]
# Probability: 0.7
#
# Next Object
# Object type: dining table
# Coordinates: [2124, 2067, 3726, 2258]
# Probability: 0.65
#
# Next Object
# Object type: person
# Coordinates: [2, 1931, 503, 2261]
# Probability: 0.64
#
# Next Object
# Object type: tie
# Coordinates: [2156, 1439, 2265, 1794]
# Probability: 0.58
#
# Next Object
# Object type: chair
# Coordinates: [2246, 1909, 2496, 2114]
# Probability: 0.42
#
# Next Object
# Object type: chair
# Coordinates: [2242, 1902, 2623, 2263]
# Probability: 0.4
#
# Next Object
# Object type: person
# Coordinates: [1207, 1668, 1439, 1943]
# Probability: 0.28
#
# Next Object
# Object type: dining table
# Coordinates: [1960, 1978, 2120, 2265]
# Probability: 0.26
#
# Next Object

# %%
results = model.predict("6.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/6.jpg: 384x640 5 persons, 3 cars, 1 bus, 1 stop sign, 1 bottle, 116.7ms
# Speed: 2.4ms preprocess, 116.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 11

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")
# Out:
# Object type: car
# Coordinates: [1, 487, 874, 1221]
# Probability: 0.94
#
# Next Object
# Object type: person
# Coordinates: [2693, 386, 3302, 1875]
# Probability: 0.92
#
# Next Object
# Object type: person
# Coordinates: [1626, 874, 3225, 2254]
# Probability: 0.91
#
# Next Object
# Object type: person
# Coordinates: [1483, 342, 2090, 1916]
# Probability: 0.91
#
# Next Object
# Object type: person
# Coordinates: [2461, 421, 2839, 983]
# Probability: 0.9
#
# Next Object
# Object type: person
# Coordinates: [1895, 369, 2153, 989]
# Probability: 0.86
#
# Next Object
# Object type: stop sign
# Coordinates: [26, 215, 128, 334]
# Probability: 0.54
#
# Next Object
# Object type: bottle
# Coordinates: [2638, 717, 2722, 944]
# Probability: 0.52
#
# Next Object
# Object type: car
# Coordinates: [1261, 330, 1610, 572]
# Probability: 0.4
#
# Next Object
# Object type: car
# Coordinates: [648, 361, 851, 528]
# Probability: 0.38
#
# Next Object
# Object type: bus
# Coordinates: [1261, 330, 1611, 571]
# Probability: 0.3
#
# Next Object

# %%
results = model.predict("7.jpg") #it returns an array with a single item. You can pass multiple images. 
#Make sure you use the correct directory. My image is under the same path as my notebook.
result = results[0] #The result contains detected objects
# Out:
# image 1/1 /Users/tcho/Library/CloudStorage/OneDrive-Personal/2025 MSBA/MSBA503 - Analytics Programming II/Take Home Assignment/7.jpg: 480x640 4 airplanes, 2 buss, 4 trucks, 133.9ms
# Speed: 3.0ms preprocess, 133.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Display the image with predictions
annotated_image = result.plot()
plt.imshow(annotated_image)
plt.axis('off')  # Turn off the axes for better visualization
plt.show()

#The code below saves the image with annotations:
# Convert the NumPy array to a PIL Image
annotated_image_pil = Image.fromarray(annotated_image)

# Save the PIL Image
annotated_image_pil.save("detected_objects_195.jpg")

# %%
len(result.boxes)
# Out:
# 10

# %%
for box in result.boxes:
  class_id = result.names[box.cls[0].item()]
  cords = box.xyxy[0].tolist()
  cords = [round(x) for x in cords]
  conf = round(box.conf[0].item(), 2)
  print("Object type:", class_id) #the ID of object type
  print("Coordinates:", cords) #the coordinates of the box as an array [x1,y1,x2,y2]
  print("Probability:", conf) #the confidence level (probability) of the model about this object using classification. If it's very low, you can ignore.
  print("\nNext Object")
# Out:
# Object type: bus
# Coordinates: [126, 471, 555, 714]
# Probability: 0.95
#
# Next Object
# Object type: bus
# Coordinates: [1, 432, 419, 640]
# Probability: 0.94
#
# Next Object
# Object type: airplane
# Coordinates: [187, 55, 979, 273]
# Probability: 0.92
#
# Next Object
# Object type: airplane
# Coordinates: [1, 122, 163, 177]
# Probability: 0.81
#
# Next Object
# Object type: airplane
# Coordinates: [405, 97, 498, 162]
# Probability: 0.57
#
# Next Object
# Object type: truck
# Coordinates: [0, 317, 143, 380]
# Probability: 0.55
#
# Next Object
# Object type: truck
# Coordinates: [74, 235, 120, 272]
# Probability: 0.55
#
# Next Object
# Object type: truck
# Coordinates: [565, 308, 598, 346]
# Probability: 0.38
#
# Next Object
# Object type: airplane
# Coordinates: [486, 112, 550, 159]
# Probability: 0.37
#
# Next Object
# Object type: truck
# Coordinates: [507, 329, 571, 388]
# Probability: 0.28
#
# Next Object
